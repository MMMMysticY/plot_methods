# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data_dir/raw_size.csv', header=None)
data.columns = ['raw_size', 'now_size','1','2','3','4']
data = data[['raw_size', 'now_size']]
data
# Out:
#      raw_size    now_size
# 0     506.241  259.848213
# 1     507.347  316.593164
# 2     520.653  163.086329
# 3     512.061  318.133995
# 4     519.176  179.317708
# ..        ...         ...
# 995   540.641  333.726625
# 996   538.602  334.600739
# 997   534.586  326.873869
# 998   532.669  185.410717
# 999   533.468  326.705866
#
# [1000 rows x 2 columns]

# %%
data.describe()
# Out:
#           raw_size     now_size
# count  1000.000000  1000.000000
# mean    634.162346   325.423189
# std     256.519287   146.913740
# min     141.102000    48.651557
# 25%     467.332750   222.995644
# 50%     662.851000   312.832315
# 75%     780.201500   421.655285
# max    1200.372000   779.148016

# %%
data.sort_values(by = 'raw_size', ascending=True, inplace=True)

# %%
data['raw_size'].values.shape
# Out:
# (1000,)

# %%
data = data.sample(frac=1)

# %%
data.to_csv('data_dir/raw_size_1.csv', header=None)

# %%
x = range(0,1000)
y1 = data['raw_size'].values
y2 = data['now_size'].values

fig, ax = plt.subplots()
ax.plot(x, y1)
ax.plot(x, y2)
plt.show();
